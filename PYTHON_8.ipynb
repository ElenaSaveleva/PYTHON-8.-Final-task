# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaSaveleva/PYTHON-8.-Final-task/blob/main/PYTHON_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Игра угадай число
Компьютер сам загадывает и сам угадывает число
"""

import numpy as np

def random_predict(number:int = 1) -> int:
    """Рандомно угадываем число

    Args:
        number (int, optional): Загаданное число. Defaults to 1.

    Returns:
        int: Число попыток
    """
    count = 0
    min = 1
    max = 100
    
    predict = max / 2
    
    while number != predict:
        count += 1
        if predict < number:
            min = predict + 1
        elif predict > number:
            max = predict - 1
        
        predict = round((min + max) / 2)
    
    print (f"Число угадано! Это число = {number}, за {count} попыток")
    return count

def score_game(random_predict) -> int:
    """За какое количство попыток в среднем за 1000 подходов угадывает наш алгоритм

    Args:
        random_predict ([type]): функция угадывания

    Returns:
        int: среднее количество попыток
    """

    count_ls = [] # список для сохранения количества попыток
    np.random.seed(1) # фиксируем сид для вопроизводимости
    random_array = np.random.randint(1, 101, size=(1000)) # загадали список чисел

    for number in random_array:
        count_ls.append(random_predict(number))

    score = int(np.mean(count_ls)) # находим среднее количество попыток

    print(f'Ваш алгоритм угадывает число в среднем за: {score} попыток')
    return(score)


if __name__ == "__main__":
     # RUN
    score_game(random_predict)
# Out:
# Число угадано! Это число = 38, за 2 попыток
# Число угадано! Это число = 13, за 6 попыток
# Число угадано! Это число = 73, за 4 попыток
# Число угадано! Это число = 10, за 5 попыток
# Число угадано! Это число = 76, за 1 попыток
# Число угадано! Это число = 6, за 3 попыток
# Число угадано! Это число = 80, за 5 попыток
# Число угадано! Это число = 65, за 6 попыток
# Число угадано! Это число = 17, за 6 попыток
# Число угадано! Это число = 2, за 5 попыток
# Число угадано! Это число = 77, за 6 попыток
# Число угадано! Это число = 72, за 5 попыток
# Число угадано! Это число = 7, за 6 попыток
# Число угадано! Это число = 26, за 5 попыток
# Число угадано! Это число = 51, за 6 попыток
# Число угадано! Это число = 21, за 6 попыток
# Число угадано! Это число = 19, за 6 попыток
# Число угадано! Это число = 85, за 4 попыток
# Число угадано! Это число = 12, за 2 попыток
# Число угадано! Это число = 29, за 6 попыток
# Число угадано! Это число = 30, за 5 попыток
# ...
